# %%
#要進行公司產業分類的資料讀取
#讀取stock_category資料
#讀取stock資料
#讀取financial_ratio資料(獲利能力)

import pymysql
stock_lst=[]
year_financial_ratio_lst=[]
category_lst=[]
operational_efficiency_lst=[]

stock_pe_lst=[]
stock_daily_date_lst=[]
book_value_lst=[]

# 開啟資料庫連線
db = pymysql.connect(host='us-cdbr-east-05.cleardb.net',
                         user='be59caf2e81229',
                         password='75242529',
                         db='heroku_da386d83e593c1d',
                         charset='utf8mb4',)
 
# 使用 cursor() 方法建立一個遊標物件 cursor
cursor = db.cursor()

# SQL 查詢語句
sql1 =  "SELECT * FROM stock"
sql2 =  "SELECT * FROM year_financial_ratio where year='2021'or year='2020'or year='2019'or year='2018'or year='2017'or year='2016'or year='2015'or year='2014'"
sql3 =  "SELECT c_name FROM stock"
sql4 =  "SELECT id,quarter,inventory_turnover,receivables_turnover_ratio,accounts_payable_turnover_ratio,fixed_asset_turnover,total_asset_turnover FROM quarter_financial_ratio where (quarter='2021Q4') or (quarter='2021Q3')or (quarter='2021Q2')or (quarter='2021Q1')or (quarter='2020Q4')"
sql5 =  "SELECT * FROM stock_pe where q='22Q1'"
sql6 =  "SELECT id,Close FROM stock_daily where Date='2022-03-31'"
sql7 =  "SELECT id,book_value_per_share FROM quarter_financial_ratio where quarter='2022Q1'"
try:

    # 執行SQL1語句
    cursor.execute(sql1)
    # 獲取所有記錄列表
    stock = cursor.fetchall()
   
    for i in stock:
        stock_lst.append(i)
    
    # 執行SQL2語句
    cursor.execute(sql2)
    # 獲取所有記錄列表
    year_financial_ratio = cursor.fetchall()
   
    for i in year_financial_ratio:
        year_financial_ratio_lst.append(i)
    print(year_financial_ratio_lst)
    
    # 執行SQL3語句
    cursor.execute(sql1)
    # 獲取所有記錄列表
    category = cursor.fetchall()
    for i in category:
        category_lst.append(i)

    
    #category_lst資料整理
    c_lst=[]
    for i in range(len(category_lst)):
        c=category_lst[i][0]
        c_lst.append(c)
    print(list(set(c_lst)))

    # 執行SQL4語句
    cursor.execute(sql4)
    # 獲取所有記錄列表
    operational_efficiency = cursor.fetchall()
    for i in operational_efficiency:
        operational_efficiency_lst.append(i)
    print(len(operational_efficiency_lst))
    
    # 執行SQL5語句
    cursor.execute(sql5)
    # 獲取所有記錄列表
    stock_pe = cursor.fetchall()
    for i in stock_pe:
        stock_pe_lst.append(i)
        
    # 執行SQL6語句
    cursor.execute(sql6)
    # 獲取所有記錄列表
    stock_daily_date = cursor.fetchall()
    for i in stock_daily_date:
        stock_daily_date_lst.append(i)

    # 執行SQL7語句
    cursor.execute(sql7)
    # 獲取所有記錄列表
    book_value = cursor.fetchall()
    for i in book_value:
        book_value_lst.append(i)

    
except:
    print("Error: unable to fetch data")

# 關閉資料庫連線
db.close()
# Out:
# [(2014, 1101, 21.02, 16.78, 14.02, 2.93, 31.95, 10.51, 5.76, 1.92, 8.98, 11.71, 9.69, 7.72, 44.46, 118.0, 140.8, 29.0, 4.08, 5.51, 9.46, 1.09, 0.41, 0.75, 44.66, 12.12), (2015, 1101, 15.51, 10.33, 7.39, 1.56, 29.26, 4.36, 2.36, -20.83, -41.59, -51.28, -58.24, -46.76, 57.25, 111.5, 133.1, 31.97, 3.59, 5.0, 8.15, 0.84, 0.32, 0.59, 46.95, 5.62), (2016, 1101, 20.08, 14.55, 9.87, 1.72, 28.92, 5.84, 3.16, -4.39, 23.77, 34.74, 27.67, 10.26, 51.14, 117.5, 141.3, 34.03, 4.22, 4.52, 8.03, 0.83, 0.32, 0.59, 44.79, 7.01), (2017, 1101, 19.24, 14.2, 10.5, 2.03, 32.11, 6.88, 3.83, 9.77, 5.18, 7.13, 16.75, 18.02, 40.39, 122.2, 142.2, 18.88, 4.02, 4.92, 9.21, 1.0, 0.36, 0.66, 43.99, 8.19), (2018, 1101, 26.96, 22.62, 18.17, 4.37, 34.2, 12.94, 7.34, 26.73, 77.61, 101.8, 119.4, 115.3, 75.2, 150.8, 171.1, 34.34, 3.71, 4.41, 10.21, 1.34, 0.4, 0.71, 42.64, 13.41), (2019, 1101, 29.25, 24.56, 20.73, 4.43, 34.23, 12.54, 7.15, -1.45, 6.9, 7.01, 12.41, 1.37, 80.52, 161.9, 177.6, 43.91, 3.04, 3.6, 9.87, 1.27, 0.35, 0.61, 43.27, 15.84), (2020, 1101, 35.32, 29.87, 26.43, 4.32, 34.41, 13.1, 7.4, -13.74, 4.16, 4.91, 9.96, -2.48, 71.33, 157.5, 172.4, 43.38, 2.58, 3.0, 8.52, 1.02, 0.28, 0.5, 43.82, 19.92), (2021, 1101, 24.9, 18.48, 19.81, 3.3, 32.37, 9.54, 5.1, 1.07, -28.75, -37.46, -24.26, -23.61, 102.7, 170.5, 191.0, 21.39, 2.74, 3.56, 7.53, 0.98, 0.26, 0.48, 48.91, 16.61), (2014, 1102, 14.33, 10.62, 14.04, 2.98, 42.19, 6.93, 4.0, 10.7, 23.08, 23.62, -10.34, -12.74, 19.6, 90.87, 108.6, 16.38, 3.64, 6.93, 7.7, 1.17, 0.28, 0.49, 42.82, 9.23), (2015, 1102, 10.65, 6.09, 7.44, 1.55, 40.43, 3.12, 1.78, -14.67, -36.58, -51.02, -54.75, -47.99, 16.9, 65.61, 81.02, 20.84, 3.09, 5.88, 7.08, 0.96, 0.24, 0.42, 42.66, 5.14), (2016, 1102, 14.09, 10.23, 7.68, 1.26, 36.49, 3.17, 1.84, -8.06, 21.67, 54.29, -5.09, -18.71, 18.23, 82.97, 103.2, 31.37, 3.26, 6.13, 7.35, 0.97, 0.24, 0.41, 41.01, 4.95), (2017, 1102, 15.67, 11.46, 10.27, 1.74, 37.91, 4.65, 2.75, 6.49, 18.42, 19.31, 42.33, 38.1, 14.35, 77.03, 93.17, 15.09, 3.36, 6.81, 8.11, 1.15, 0.27, 0.45, 40.99, 5.8), (2018, 1102, 25.59, 21.94, 17.99, 3.54, 41.02, 9.77, 5.66, 27.49, 108.2, 144.1, 123.4, 103.4, 23.77, 108.9, 128.0, 17.05, 3.48, 6.93, 7.52, 1.56, 0.31, 0.54, 43.03, 13.17), (2019, 1102, 28.64, 24.69, 24.9, 5.56, 43.45, 13.54, 7.72, 7.98, 20.85, 21.54, 49.4, 57.06, 33.28, 106.5, 120.1, 50.14, 3.65, 5.18, 7.25, 1.65, 0.31, 0.54, 43.0, 16.6), (2020, 1102, 29.82, 25.14, 23.99, 4.7, 43.96, 11.07, 6.32, -12.43, -8.82, -10.85, -15.6, -15.47, 40.47, 123.1, 135.9, 30.65, 3.92, 4.21, 7.63, 1.38, 0.26, 0.46, 42.82, 21.75), (2021, 1102, 23.62, 19.73, 19.55, 4.7, 44.26, 10.01, 5.71, 14.59, -9.21, -10.09, -6.64, 0.0, 47.06, 133.4, 149.1, 12.09, 5.02, 5.5, 8.89, 1.73, 0.29, 0.51, 43.14, 25.53), (2014, 1103, 5.57, -6.57, 1.37, 0.03, 26.88, 0.26, 0.16, -7.75, -6.62, -162.2, -95.83, -98.48, 93.98, 280.3, 382.6, 13.76, 4.43, 4.28, 3.02, 1.18, 0.12, 0.19, 42.73, 1.05), (2015, 1103, -3.81, 14.47, 7.55, 0.34, 19.23, 1.28, 0.7, -28.22, -149.1, 258.0, 296.6, 1033.0, 119.8, 420.6, 699.9, 19.88, 4.03, 3.93, 2.47, 1.04, 0.09, 0.17, 48.7, 1.86), (2016, 1103, 3.04, -14.57, 0.31, 0.04, 21.92, 0.07, 0.04, 11.1, 188.6, -211.9, -95.4, -88.24, 118.1, 347.0, 476.6, 20.94, 2.78, 4.49, 2.99, 1.44, 0.12, 0.21, 39.48, 1.41), (2017, 1103, 14.74, -3.07, 46.91, 1.39, 27.21, 5.57, 3.59, -33.66, 221.8, 86.03, 9866.0, 3375.0, 77.82, 227.8, 393.0, 17.41, 1.92, 3.25, 2.34, 0.85, 0.08, 0.12, 31.98, 14.28), (2018, 1103, 13.79, -4.95, 36.76, 1.09, 29.68, 3.83, 2.55, 0.44, -6.06, -62.15, -21.3, -21.58, 61.64, 199.8, 349.0, -19.9, 4.54, 3.07, 2.56, 0.66, 0.07, 0.1, 34.6, 5.93), (2019, 1103, 10.54, -23.08, 74.77, 2.02, 35.4, 6.32, 3.98, -9.96, -31.16, -319.7, 83.15, 85.32, 55.86, 283.7, 288.0, -4.57, 3.0, 1.83, 4.56, 0.32, 0.05, 0.08, 38.85, 8.85), (2020, 1103, -6.98, 39.96, 89.29, 2.74, 37.61, 7.55, 4.63, 9.26, -172.4, 289.2, 30.48, 35.64, 111.0, 380.0, 385.4, 17.45, 3.83, 2.84, 41.39, 0.25, 0.05, 0.08, 38.45, 13.87), (2021, 1103, 1.39, -23.67, 33.67, 1.02, 38.74, 2.94 ...
# 4793

# %% [markdown]
# # 獲利能力
# #正相關,年複合成長率(是否穩定成長)
# #1.營收年成長率：穩定成長公司(近五年不斷成長)
# #2.毛利率：暫不做比較，不同產業比較沒意義
# #3.稅後淨利率：大於10%才算是有水準公司
# #4.營業利益率：穩定的公司(近五年不斷成長)，且產業相比值相對較高(大於產業平均)
# #5.股東權益報酬率：近八年大於15%(近四季ROE大於15％，且近十年ROE高於15％)
# #6.資產報酬率：近八年大於8%

# %%
import pandas as pd
from scipy.stats import linregress
import matplotlib.pyplot as plt
# %matplotlib inline
profitability=[]
for i in range(len(stock_lst)):
    stock_id1=str(stock_lst[i][0])
    year_eps_lst=[]
    for j in range(len(year_financial_ratio_lst)):
        stock_id2=str(year_financial_ratio_lst[j][1])
        year=str(year_financial_ratio_lst[j][0])
        if stock_id1==stock_id2:
            if year=="2021" or year=="2020" or year=="2019" or year=="2018" or year=="2017":
                year=int(year)
                eps=year_financial_ratio_lst[j][5]
                year_eps=year,eps
                year_eps_lst.append(year_eps)
                now_id=stock_id2
    df=pd.DataFrame(year_eps_lst)
    if df.empty:
        continue
        
    else:
        df.columns = ['year','eps']
        c=df.iloc[::-1] 
        c.reset_index(drop=True, inplace=True)
        reg_up = linregress(x =c.year,y =c.eps)
        slope=reg_up.slope
         
        if slope>0.3:
#             id_lst.append(now_id)
            year_net_lst=[]
            for z in range(len(year_financial_ratio_lst)):
                stock_id2=str(year_financial_ratio_lst[z][1])
                year=str(year_financial_ratio_lst[z][0])
                if now_id==stock_id2:
                    if year=="2021" or year=="2020" or year=="2019" or year=="2018" or year=="2017":
                        year=int(year)
                        net=year_financial_ratio_lst[z][4]
                        year_net=year,net
                        year_net_lst.append(year_net)
                        
            df=pd.DataFrame(year_net_lst)
            if df.empty:
                continue

            else:
                df.columns = ['year','net']
                c=df.iloc[::-1] 
                c.reset_index(drop=True, inplace=True)
                reg_up = linregress(x =c.year,y =c.net)
                slope=reg_up.slope  
                if slope>0.3:
#                     ROE_num=0
#                     for z in range(len(financial_ratio_lst)):
#                         stock_id2=str(financial_ratio_lst[z][0])
#                         if now_id==stock_id2:
#                             ROE_quarter=financial_ratio_lst[z][5]
#                             if ROE_quarter>7:
#                                 ROE_num+=1
#                     if ROE_num==4:
                    ROE_num=0
                    ROA_num=0
                    for m in range(len(year_financial_ratio_lst)):
                        stock_id2=str(year_financial_ratio_lst[m][1])
                        if now_id==stock_id2:
                            ROE_year=year_financial_ratio_lst[m][7]
                            ROA_year=year_financial_ratio_lst[m][8]
                            if ROE_year==None:
                                continue
                            else:

                                if ROE_year>10:
                                    ROE_num+=1

                                if ROA_year>8:
                                    ROA_num+=1
                                    if ROE_num==8 and ROA_num==8:
                                        profitability.append(now_id)
                                else:
                                    break
                                            
                                        
                                
print(profitability)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\user\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# ['1232', '1256', '1477', '1773', '2059', '2114', '2330', '2383', '2428', '2441', '2455', '3034', '4137', '4952', '5269', '6202', '6415', '6582', '8016', '8464', '8481', '8499']

# %% [markdown]
# # 經營效率
# #依產業做比較，並找出高於產業平均的公司

# %%
#將公司進行產業分類
company_category=[]
for i in c_lst:
    c=i
    i=[]
    
    for j in range(len(stock_lst)):
        stock_lst_id=stock_lst[j][0]
        stock_lst_category=stock_lst[j][2]

        if stock_lst_category==c:
            i.append(stock_lst_id)
   
    category_id=c,i
    company_category.append(category_id)
# print(company_category)        

#存貨大於產業平均的公司
inventory_turnover_lst=[]
ccc=[]
for i in range(len(company_category)):  
    industry=company_category[i][0]
    industry_id=company_category[i][1]
    sum=0
    count=0
    for j in industry_id:
        str_j=str(j)
        for z in range(len(operational_efficiency_lst)):
            operational_efficiency_id=str(operational_efficiency_lst[z][0])
            operational_efficiency_date=operational_efficiency_lst[z][1]
            if str_j==operational_efficiency_id:
                if operational_efficiency_date=="2021Q4":
                    inventory_turnover=operational_efficiency_lst[z][2]
                    if inventory_turnover==None:
                        continue
                    else:
                        inventory_turnover=float(inventory_turnover)

                        sum+=inventory_turnover
                        count+=1
    id_lst=[]
    if count==0:
        id_lst.append([])
    
    
    else:
        inventory_turnover_average=sum/count
        
        for j in industry_id:
            str_j=str(j)
            for z in range(len(operational_efficiency_lst)):
                operational_efficiency_id=str(operational_efficiency_lst[z][0])
                operational_efficiency_date=operational_efficiency_lst[z][1]
                if str_j==operational_efficiency_id:
                    if operational_efficiency_date=="2021Q4":
                        inventory_turnover=operational_efficiency_lst[z][2]
                        if inventory_turnover==None:
                            continue
                        else:
                            inventory_turnover=float(inventory_turnover)
                            if inventory_turnover_average<inventory_turnover:
#                                 id_lst.append(operational_efficiency_id)
                                inventory_turnover_lst.append(operational_efficiency_id)

#     industry_id_lst=industry,id_lst
#     inventory_turnover_lst.append(id_lst)
# print(inventory_turnover_lst)
    
                
              


#總資產周轉率大於產業平均的公司
asset_turnover_lst=[]
for i in range(len(company_category)):  
    industry=company_category[i][0]
    industry_id=company_category[i][1]
    sum=0
    count=0
    if industry_id==[]:
        id_lst=[]
    else:
        for j in industry_id:
            str_j=str(j)

            for z in range(len(operational_efficiency_lst)):
                operational_efficiency_id=str(operational_efficiency_lst[z][0])
                operational_efficiency_date=operational_efficiency_lst[z][1]
                if str_j==operational_efficiency_id:
                    if operational_efficiency_date=="2021Q4":
                        assets_turnover=float(operational_efficiency_lst[z][6])
                        sum+=assets_turnover
                        count+=1
        if count!=0:
            
            assets_turnover_average=sum/count
            id_lst=[]
            for j in industry_id:
                str_j=str(j)
                for z in range(len(operational_efficiency_lst)):
                    operational_efficiency_id=str(operational_efficiency_lst[z][0])
                    operational_efficiency_date=operational_efficiency_lst[z][1]
                    if str_j==operational_efficiency_id:
                        if operational_efficiency_date=="2021Q4":
                            assets_turnover=float(operational_efficiency_lst[z][6])
                            if assets_turnover_average<assets_turnover:
#                                 id_lst.append(operational_efficiency_id)
                                asset_turnover_lst.append(operational_efficiency_id)
#     industry_id_lst=industry,id_lst
#     asset_turnover_lst.append(industry_id_lst)
# print(asset_turnover_lst)
    
                
#固定資產周轉率大於產業平均的公司
fixed_asset_turnover_lst=[]
for i in range(len(company_category)):  
    industry=company_category[i][0]
    industry_id=company_category[i][1]
    sum=0
    count=0
    if industry_id==[]:
        id_lst=[]
    else:
        for j in industry_id:
            str_j=str(j)

            for z in range(len(operational_efficiency_lst)):
                operational_efficiency_id=str(operational_efficiency_lst[z][0])
                operational_efficiency_date=operational_efficiency_lst[z][1]
                if str_j==operational_efficiency_id:
                    if operational_efficiency_date=="2021Q4":
                        fixed_assets_turnover=float(operational_efficiency_lst[z][5])
                        sum+=fixed_assets_turnover
                        count+=1
        if count!=0:
            fixed_assets_turnover_average=sum/count
            id_lst=[]
            for j in industry_id:
                str_j=str(j)
                for z in range(len(operational_efficiency_lst)):
                    operational_efficiency_id=str(operational_efficiency_lst[z][0])
                    operational_efficiency_date=operational_efficiency_lst[z][1]
                    if str_j==operational_efficiency_id:
                        if operational_efficiency_date=="2021Q4":
                            fixed_assets_turnover=float(operational_efficiency_lst[z][5])
                            if fixed_assets_turnover_average<fixed_assets_turnover:
#                                 id_lst.append(operational_efficiency_id)
                                fixed_asset_turnover_lst.append(operational_efficiency_id)
#     industry_id_lst=industry,id_lst
#     fixed_asset_turnover_lst.append(industry_id_lst)
# print(fixed_asset_turnover_lst)


#應付帳款周轉率小於產業平均的公司
APTR_lst=[]
for i in range(len(company_category)):  
    industry=company_category[i][0]
    industry_id=company_category[i][1]
    sum=0
    count=0
    if industry_id==[]:
        id_lst=[]
    else:
        for j in industry_id:
            str_j=str(j)
            for z in range(len(operational_efficiency_lst)):
                operational_efficiency_id=str(operational_efficiency_lst[z][0])
                operational_efficiency_date=operational_efficiency_lst[z][1]
                if str_j==operational_efficiency_id:
                    if operational_efficiency_date=="2021Q4":
                        accounts_payable_turnover_ratio=operational_efficiency_lst[z][4]
                        if accounts_payable_turnover_ratio==None:
                            continue
                        else:
                            accounts_payable_turnover_ratio=float(accounts_payable_turnover_ratio)
                            sum+=accounts_payable_turnover_ratio
                            count+=1
        if count!=0:
            accounts_payable_turnover_ratio_average=sum/count
            id_lst=[]
            for j in industry_id:
                str_j=str(j)

                for z in range(len(operational_efficiency_lst)):
                    operational_efficiency_id=str(operational_efficiency_lst[z][0])
                    operational_efficiency_date=operational_efficiency_lst[z][1]
                    if str_j==operational_efficiency_id:
                        if operational_efficiency_date=="2021Q4":
                            accounts_payable_turnover_ratio=operational_efficiency_lst[z][4]
                            if accounts_payable_turnover_ratio==None:
                                continue
                            else:
                                accounts_payable_turnover_ratio=float(accounts_payable_turnover_ratio)
                                if accounts_payable_turnover_ratio_average>accounts_payable_turnover_ratio:
#                                     id_lst.append(operational_efficiency_id)
                                    APTR_lst.append(operational_efficiency_id)
#     APTR_lst.append(industry_id_lst)
# print(APTR_lst)

#應收帳款周轉率大於產業平均的公司
RTR_lst=[]                                                    
for i in range(len(company_category)):  
    industry=company_category[i][0]
    industry_id=company_category[i][1]
    sum=0
    count=0    
    if industry_id==[]:
        id_lst=[]
    else:
        for j in industry_id:
            str_j=str(j)
            for z in range(len(operational_efficiency_lst)):
                operational_efficiency_id=str(operational_efficiency_lst[z][0])
                operational_efficiency_date=operational_efficiency_lst[z][1]
                if str_j==operational_efficiency_id:
                    if operational_efficiency_date=="2021Q4":
                        receivables_turnover_ratio=operational_efficiency_lst[z][3]
                        if receivables_turnover_ratio==None:
                            continue
                        else:
                            receivables_turnover_ratio=float(receivables_turnover_ratio)
                            sum+=receivables_turnover_ratio
                            count+=1
        if count!=0:
            
            receivables_turnover_ratio_average=sum/count
            id_lst=[]
            for j in industry_id:
                str_j=str(j)
                for z in range(len(operational_efficiency_lst)):
                    operational_efficiency_id=str(operational_efficiency_lst[z][0])
                    operational_efficiency_date=operational_efficiency_lst[z][1]
                    if str_j==operational_efficiency_id:
                        if operational_efficiency_date=="2021Q4":
                            receivables_turnover_ratio=operational_efficiency_lst[z][3]
                            if receivables_turnover_ratio==None:
                                continue
                            else:
                                receivables_turnover_ratio=float(receivables_turnover_ratio)
                                if receivables_turnover_ratio_average<receivables_turnover_ratio:
#                                     id_lst.append(operational_efficiency_id)
                                    RTR_lst.append(operational_efficiency_id)
#     industry_id_lst=industry,id_lst
#     RTR_lst.append(industry_id_lst)
# print(RTR_lst)

# %%
all_score_id_lst=[]
score_id_lst=[]
import sys
count=0
class id_score:
    def __init__(self):
        self.id=''
        self.score=0
        self.next=None  

ptr=None
prev=None
current=None

head=id_score()
head.next=None
for i in range(len(stock_lst)):
    
    stock_id1=str(stock_lst[i][0])
    score0=0
  
    if stock_id1 in inventory_turnover_lst:
        
        score0+=1
     
    if stock_id1 in asset_turnover_lst:
        score0+=1
    if stock_id1 in fixed_asset_turnover_lst:
        score0+=1
    if stock_id1 in APTR_lst:
        score0+=1
    if stock_id1 in RTR_lst:
        score0+=1
                        
    if score0==0:
        continue
    else:
        ptr=id_score()
        ptr.next=None
        ptr.id=stock_id1
        ptr.score=score0

        prev=head
        current=head.next
        while current!=None and current.score>=ptr.score:
            prev=current
            current=current.next
        prev.next=ptr
        ptr.next=current
                                
current=head.next
while current!= None:
    company_id=current.id
    all_score_id_lst.append(company_id)
    company_score=current.score

#     print(company_id,company_score)
    count+=1
    current=current.next
#     score_id_lst.append(company_id)
# category_score_id_lst=industry,score_id_lst
# all_score_id_lst.append(score_id_lst)
# print(all_score_id_lst)

# %% [markdown]
# # 償還能力
# #1.流動比大於200%
# #2.速動比大於100%
# #3.利息保障倍數大於2倍
# #3.現金流動比大於100%

# %%
pay_lst=[]
for i in range(len(stock_lst)):
    stock_id1=str(stock_lst[i][0])
    num=0
    for j in range(len(year_financial_ratio_lst)):
        stock_id2=str(year_financial_ratio_lst[j][1])
        year=str(year_financial_ratio_lst[j][0])
        
        if stock_id1==stock_id2:
           
            if year=="2021": #or year=="2020":# or year=="2019":
                current_ratio=year_financial_ratio_lst[j][16]
                quick_ratio=year_financial_ratio_lst[j][15]
                tie=year_financial_ratio_lst[j][25]
                cash_flow_ratio=year_financial_ratio_lst[j][17]
                if current_ratio==None or quick_ratio==None or tie==None or cash_flow_ratio==None:
                    break
                else:
                    if current_ratio>200:
                        print(stock_id1)
                        if quick_ratio>100:
                            if tie>2:
                                if cash_flow_ratio>100:
                                    num+=1
                                    if num==1:
                                        pay_lst.append(stock_id2)

# print(pay_lst)
# Out:
# 1103
# 1109
# 1203
# 1220
# 1227
# 1232
# 1234
# 1235
# 1256
# 1301
# 1303
# 1304
# 1305
# 1307
# 1308
# 1309
# 1312
# 1313
# 1314
# 1315
# 1323
# 1324
# 1325
# 1326
# 1337
# 1340
# 1342
# 1410
# 1416
# 1417
# 1418
# 1423
# 1434
# 1435
# 1437
# 1439
# 1442
# 1445
# 1451
# 1452
# 1453
# 1454
# 1463
# 1465
# 1470
# 1471
# 1475
# 1476
# 1477
# 1504
# 1516
# 1525
# 1529
# 1531
# 1537
# 1540
# 1558
# 1582
# 1590
# 1597
# 1611
# 1612
# 1614
# 1618
# 1702
# 1711
# 1714
# 1720
# 1725
# 1726
# 1730
# 1731
# 1732
# 1733
# 1737
# 1762
# 1776
# 1783
# 1786
# 1789
# 1805
# 1809
# 1817
# 1903
# 2012
# 2015
# 2022
# 2027
# 2028
# 2029
# 2032
# 2033
# 2059
# 2102
# 2106
# 2107
# 2108
# 2114
# 2115
# 2204
# 2211
# 2227
# 2228
# 2233
# 2236
# 2241
# 2247
# 2302
# 2303
# 2305
# 2323
# 2330
# 2332
# 2337
# 2340
# 2342
# 2344
# 2348
# 2351
# 2355
# 2358
# 2363
# 2365
# 2369
# 2374
# 2388
# 2390
# 2395
# 2399
# 2401
# 2402
# 2405
# 2408
# 2417
# 2420
# 2423
# 2425
# 2426
# 2428
# 2431
# 2434
# 2436
# 2438
# 2443
# 2451
# 2458
# 2459
# 2461
# 2468
# 2471
# 2472
# 2474
# 2476
# 2477
# 2478
# 2482
# 2484
# 2485
# 2486
# 2489
# 2491
# 2493
# 2495
# 2509
# 2511
# 2515
# 2524
# 2528
# 2530
# 2535
# 2539
# 2603
# 2605
# 2607
# 2609
# 2611
# 2615
# 2617
# 2636
# 2706
# 2901
# 2913
# 2915
# 2923
# 2929
# 2936
# 2939
# 3002
# 3003
# 3006
# 3008
# 3014
# 3016
# 3019
# 3022
# 3024
# 3025
# 3026
# 3030
# 3031
# 3034
# 3035
# 3038
# 3041
# 3042
# 3049
# 3051
# 3054
# 3057
# 3062
# 3094
# 3138
# 3164
# 3167
# 3257
# 3308
# 3311
# 3356
# 3376
# 3413
# 3416
# 3419
# 3432
# 3437
# 3501
# 3504
# 3515
# 3518
# 3530
# 3532
# 3533
# 3543
# 3545
# 3563
# 3588
# 3591
# 3622
# 3653
# 3661
# 3673
# 3679
# 3686
# 3701
# 3714
# 4108
# 4133
# 4137
# 4142
# 4148
# 4155
# 4164
# 4440
# 4536
# 4540
# 4552
# 4555
# 4560
# 4571
# 4572
# 4576
# 4722
# 4739
# 4764
# 4770
# 4807
# 4912
# 4919
# 4930
# 4935
# 4942
# 4952
# 4956
# 4960
# 4961
# 4967
# 4968
# 4976
# 4977
# 4989
# 4994
# 4999
# 5007
# 5203
# 5215
# 5222
# 5234
# 5244
# 5269
# 5283
# 5285
# 5515
# 5519
# 5521
# 5533
# 5538
# 5546
# 6115
# 6116
# 6136
# 6142
# 6168
# 6184
# 6192
# 6197
# 6201
# 6202
# 6205
# 6206
# 6209
# 6214
# 6215
# 6224
# 6225
# 6239
# 6243
# 6269
# 6271
# 6277
# 6283
# 6405
# 6415
# 6416
# 6426
# 6442
# 6451
# 6505
# 6515
# 6531
# 6533
# 6541
# 6552
# 6579
# 6582
# 6598
# 6641
# 6666
# 6671
# 6719
# 6756
# 6768
# 6770
# 6781
# 6792
# 6806
# 8016
# 8021
# 8033
# 8039
# 8046
# 8072
# 8081
# 8103
# 8131
# 8150
# 8201
# 8222
# 8374
# 8422
# 8429
# 8464
# 8481
# 8499
# 9902
# 9905
# 9908
# 9918
# 9919
# 9924
# 9927
# 9940
# 9942
# 9944
# 9945
# 9946
# ['1256', '1308', '1410', '1416', '1423', '1783', '2107', '2108', '2247', '2330', '2344', '2408', '2451', '2458', '2603', '2609', '2615', '2617', '3006', '3034', '3049', '3094', '3257', '3432', '3532', '4133', '4440', '5222', '6116', '6202', '6239', '6271', '6277', '6415', '6426', '6531', '6533', '6552', '6582', '6756', '8016', '8046', '8131', '8150', '8422', '9902', '9927']

# %% [markdown]
# # 價值

# %%
#beta值
import requests
from bs4 import BeautifulSoup
import pandas as pd
import random
id = pd.read_csv('C:/Users/user/aphla_beta.csv')
lst=id.values.tolist()
#分類景氣股及非景氣股

cyclical_id=[]
non_cyclical_id=[]
id_lst=[]
for i in range(len(stock_lst)):
    stock_id1=str(stock_lst[i][0])
    for z in range(len(lst)):
        beta_id=str(int(lst[z][1]))
        if stock_id1==beta_id:
            beta_value=lst[z][3]
            if beta_value<1:
                cyclical_id.append(beta_id)
                for j in range(len(stock_pe_lst)):
                    pe_id=str(stock_pe_lst[j][0])
                    if pe_id==beta_id:
                        pe=stock_pe_lst[j][1]
                        if pe==None:
                            continue
                        else:
                            if pe<12:
                                id_lst.append(pe_id)
            else:
                non_cyclical_id.append(beta_id)
                for j in range(len(book_value_lst)):
                    pb_id=str(book_value_lst[j][0])
                    if pb_id==beta_id:
                        pb=float(book_value_lst[j][0])
                        
                        for z in range(len(stock_daily_date_lst)):
                            close_id=stock_daily_date_lst[z][0]
                            if close_id==beta_id:
                                close=stock_daily_date_lst[z][1]
                                PBR=close/pb
                                if PBR<1:
                                    id_lst.append(pb_id)

# %%
id_lst1=[]
for i in profitability:
    if i in pay_lst:
        if i in id_lst:
            id_lst1.append(i)

# %%
import pandas as pd
final=pd.DataFrame(id_lst1)
final.columns = ['id']
final.insert(0, 'industry','綜合推薦')
final
# Out:
#   industry    id
# 0     綜合推薦  6582

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://be59caf2e81229:75242529@us-cdbr-east-05.cleardb.net:3306/heroku_da386d83e593c1d")

# Connect to the database
connection = pymysql.connect(host='us-cdbr-east-05.cleardb.net',
                         user='be59caf2e81229',
                         password='75242529',
                         db='heroku_da386d83e593c1d',
                         charset='utf8mb4',)    

# create cursor
cursor=connection.cursor()
# Execute the to_sql for writting DF into SQL
final.to_sql('stock_recom', engine, if_exists='append', index=False)    

# Execute query
sql = "SELECT * FROM `stock_recom`"
cursor.execute(sql)

# Fetch all the records
result = cursor.fetchall()


for i in result:
    
    print(i)


engine.dispose()
connection.close()
# Out:
# ('光電業', 3481)
# ('光電業', 4935)
# ('光電業', 6706)
# ('其他業', 5871)
# ('其他業', 6655)
# ('其他業', 8478)
# ('其他電子業', 2360)
# ('其他電子業', 2390)
# ('其他電子業', 6438)
# ('化學工業', 4763)
# ('半導體業', 6531)
# ('半導體業', 8016)
# ('半導體業', 8081)
# ('塑膠工業', 1308)
# ('塑膠工業', 1312)
# ('建材營造業', 2527)
# ('建材營造業', 2540)
# ('建材營造業', 2545)
# ('橡膠工業', 2108)
# ('橡膠工業', 2114)
# ('橡膠工業', 6582)
# ('水泥工業', 1102)
# ('汽車工業', 2115)
# ('汽車工業', 2201)
# ('油電燃氣業', 0)
# ('玻璃陶瓷', 1810)
# ('生技醫療業', 1720)
# ('生技醫療業', 1795)
# ('生技醫療業', 4137)
# ('紡織纖維', 1459)
# ('綜合推薦', 2330)
# ('綜合推薦', 3034)
# ('綜合推薦', 6415)
# ('綜合推薦', 6582)
# ('綜合推薦', 8016)
# ('航運業', 2603)
# ('航運業', 2609)
# ('航運業', 2636)
# ('觀光事業', 2707)
# ('貿易百貨業', 5906)
# ('資訊服務業', 2471)
# ('通信網路業', 3138)
# ('通信網路業', 3669)
# ('造紙工業', 6790)
# ('金融保險業', 2855)
# ('金融保險業', 6005)
# ('鋼鐵工業', 2006)
# ('鋼鐵工業', 2028)
# ('鋼鐵工業', 2031)
# ('電器電纜', 1612)
# ('電子通路業', 0)
# ('電子零組件業', 2428)
# ('電子零組件業', 6781)
# ('電子零組件業', 8046)
# ('電機機械', 1513)
# ('電機機械', 1526)
# ('電腦及週邊設備業', 2376)
# ('電腦及週邊設備業', 3515)
# ('電腦及週邊設備業', 3706)
# ('食品工業', 0)
